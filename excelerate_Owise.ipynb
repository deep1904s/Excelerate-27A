# %%
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("/Users/macbook/Prodigy Info Tech Data Science Internship/Excelerate-27A/Opportunity Wise Data 1.csv")

# Display the first few rows
df.head()
# Out:
#                              Profile Id                  Opportunity Id  \
# 0  31ce84c2-2bd1-40ba-b2d8-f164fe125306  00000000-0G4F-19XB-EXPW-KS8F3N
# 1  36814990-f854-4f76-8c63-91f27567d080  00000000-0G4F-19XB-EXPW-KS8F3N
# 2  8154328c-f8fe-4bd1-af05-783e140f68b5  00000000-0G4F-19XB-EXPW-KS8F3N
# 3  a83abad6-db1e-44c4-a8f4-9e397e282d73  00000000-0G4F-19XB-EXPW-KS8F3N
# 4  c2b8a15f-2ba3-41e4-a553-7ca68b0d4a54  00000000-0G4F-19XB-EXPW-KS8F3N
#
#                               Opportunity Name Opportunity Category  \
# 0  Statement of Purpose (SOP) Writing Workshop                Event
# 1  Statement of Purpose (SOP) Writing Workshop                Event
# 2  Statement of Purpose (SOP) Writing Workshop                Event
# 3  Statement of Purpose (SOP) Writing Workshop                Event
# 4  Statement of Purpose (SOP) Writing Workshop                Event
#
#   Opportunity End Date  Gender       City           State      Country  \
# ...

# %%
df.isnull().sum()
# Out:
# Profile Id                   0
# Opportunity Id               0
# Opportunity Name             0
# Opportunity Category         0
# Opportunity End Date         0
# Gender                       0
# City                         0
# State                       12
# Country                      0
# Zip Code                    12
# Graduation Date(YYYY MM)     0
# Current Student Status       0
# Current/Intended Major      40
# Status Description           0
# Apply Date                   0
# Apply Time                   0
# Opportunity Start Date       0
# Reward Amount                0
# Badge Id                     0
# Badge Name                   0
# Skill Points Earned          0
# Skills Earned                0
# dtype: int64

# %%
df.shape
# Out:
# (20322, 22)

# %%
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100
print(missing_percent[missing_percent > 0])  # Show only columns with missing values
# Out:
# State                     0.059049
# Zip Code                  0.059049
# Current/Intended Major    0.196831
# dtype: float64

# %%
df["Opportunity Category"].value_counts().head(10)
# Out:
# Opportunity Category
# Internship     15360
# Event           2007
# Course          1730
# Competition     1121
# Engagement       104
# Name: count, dtype: int64

# %%
#Most popular Opportunity category
plt.figure(figsize=(10, 5))
df["Opportunity Category"].value_counts().head(10).plot(kind="bar", color="skyblue")
plt.title("Top 10 Opportunity Categories")
plt.xlabel("Opportunity Category")
plt.ylabel("Number of Sign-Ups")
plt.xticks(rotation=45)  # Rotate labels for better visibility
plt.show()

# %%
#opportunity sign up trend over time

df["Apply Date"] = pd.to_datetime(df["Apply Date"])
df.groupby(df["Apply Date"].dt.month)["Profile Id"].count().plot(kind="bar", figsize=(10,5))
plt.title("Monthly Sign-Up Trends")
plt.xlabel("Month")
plt.ylabel("Number of Sign-Ups")
plt.show()

# %%
#
completion_rate.plot(kind="bar", stacked=True, figsize=(12, 6), colormap="tab10")
plt.title("Completion Rates by Opportunity (Stacked)")
plt.xlabel("Opportunity Name")
plt.ylabel("Proportion of Users")
plt.xticks(rotation=45, ha="right")
plt.legend(title="Status Description")
plt.show()

# %%
#demographic breakdown
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Gender Distribution")
plt.show()

# %%
#States with Most Sign-Ups
df["State"].value_counts().head(5).plot(kind="bar", figsize=(8,5))
plt.title("Top 5 States with Most Sign-Ups")
plt.xlabel("State")
plt.ylabel("Count")
plt.show()
